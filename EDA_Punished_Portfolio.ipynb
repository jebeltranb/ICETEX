# %% [markdown]
# # Analisis esploratorio de datos - *Cartera castigada*

# %%
import missingno as msno
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
import xlrd

# %%
df = pd.read_csv("data/Punished_portfolio_data.csv", sep = '|')
df.shape
# Out:
# c:\users\dielesro\pip_envs\icetex\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# (48992, 51)

# %%
df
# Out:
#        IDSOLICITUD         FECHAENTRADA          FECHASALIDA  \
# 0              280  2020-11-17 00:00:00                  NaN
# 1              372  2020-11-10 00:00:00  2020-11-17 00:00:00
# 2             1132  2020-11-10 00:00:00  2020-11-17 00:00:00
# 3             3518  2020-11-01 00:00:00  2020-11-17 00:00:00
# 4             5648  2020-11-17 00:00:00                  NaN
# ...            ...                  ...                  ...
# 48987      1214479  2018-11-01 00:00:00  2019-11-12 00:00:00
# 48988      1522420  2018-11-01 00:00:00  2019-11-12 00:00:00
# 48989      1731356  2018-11-01 00:00:00  2019-11-12 00:00:00
# 48990      1733481  2018-11-01 00:00:00  2019-11-12 00:00:00
# 48991      2445369  2018-11-01 00:00:00  2019-11-12 00:00:00
#
#         FECHAACTUALIZACION       FECHAMORADESDE  NROCUOTASMORA  \
# 0      2020-11-17 00:00:00                  NaN            0.0
# 1      2020-11-17 00:00:00                  NaN            0.0
# 2      2020-11-17 00:00:00                  NaN            0.0
# 3      2020-11-17 00:00:00  2020-03-05 00:00:00            7.0
# 4      2020-11-17 00:00:00  2020-10-10 00:00:00            1.0
# ...                    ...                  ...            ...
# 48987  2018-11-01 00:00:00                43200            6.0
# 48988  2018-11-01 00:00:00                42202           39.0
# 48989  2018-11-01 00:00:00                42264           13.0
# 48990  2018-11-01 00:00:00                42355           34.0
# 48991  2018-11-01 00:00:00                42389            6.0
#
#        NUMDIASMORA_ACT  VALORCUOTA  SALDOTOTALMORA1_ACT  SALDOTOTAL_ACT  ...  \
# 0                120.0   218384.59           1019023.62      8729010.51  ...
# 1                701.0   145209.36           6301309.74      7066075.21  ...
# 2                262.0   167036.95           1083254.16     11090703.17  ...
# 3                789.0   186526.37           4267405.65      5183437.57  ...
# 4               1291.0   331863.91          24689024.56     24689024.56  ...
# ...                ...         ...                  ...             ...  ...
# 48987              NaN   204986.00                  NaN             NaN  ...
# 48988              NaN   132792.00                  NaN             NaN  ...
# 48989              NaN    72108.00                  NaN             NaN  ...
# 48990              NaN    84446.00                  NaN             NaN  ...
# 48991              NaN   326242.00                  NaN             NaN  ...
#
#       CUOTAS_PAGADAS_ACUERDO CUOTAS_MORA_ACUERDO CUOTAS_FUTURAS_ACUERDO  \
# 0                        0.0                 1.0                    0.0
# 1                        NaN                 NaN                    NaN
# 2                        0.0                 1.0                    0.0
# 3                        NaN                 NaN                    NaN
# 4                        1.0                 0.0                    0.0
# ...                      ...                 ...                    ...
# 48987                    1.0                 0.0                    0.0
# 48988                    NaN                 NaN                    NaN
# 48989                    0.0                 1.0                    0.0
# 48990                    NaN                 NaN                    NaN
# 48991                    0.0                 1.0                    0.0
#
#       fecha Venc Cuota Vigente Valor Cuota Vigente  No. ACUERDOS DE PAGO  \
# 0              10/02/2020 0:00              287094                   3.0
# 1                          NaN                 NaN                   NaN
# 2              20/02/2020 0:00                   0                   8.0
# 3                          NaN                   0                   6.0
# 4              10/02/2020 0:00                   0                   2.0
# ...                        ...                 ...                   ...
# 48987          10/02/2020 0:00                   0                   1.0
# 48988                      NaN                 NaN                   NaN
# 48989                      NaN                   0                   4.0
# 48990                      NaN                   0                   2.0
# 48991                      NaN                   0                   4.0
#
#                 RazonSocial TelEmpleador  UltimoPeriodoCotizado  \
# 0                       NaN          NaN                    NaN
# 1                       NaN          NaN                    NaN
# 2                       NaN          NaN                    NaN
# 3                       NaN          NaN                    NaN
# 4      INDRA COLOMBIA S A S    6463600.0                2020-10
# ...                     ...          ...                    ...
# 48987                   NaN          NaN                    NaN
# 48988                   NaN          NaN                    NaN
# 48989                   NaN          NaN                    NaN
# 48990                   NaN          NaN                    NaN
# 48991                   NaN          NaN                    NaN
#
#                FechaFosyga
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4      2020-10-01 00:00:00
# ...                    ...
# 48987                  NaN
# 48988                  NaN
# 48989                  NaN
# 48990                  NaN
# 48991                  NaN
#
# [48992 rows x 51 columns]

# %%
#plt.rcParams.update({'font.size': 25})
plt.figure(figsize=(25,10))
sns.heatmap(df.isnull(), cbar=False)
plt.title("Cartera castigada data")
plt.xlabel('Variable')
plt.ylabel('Fila')
# Out:
# Text(204.0, 0.5, 'Fila')
